# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import plotly.graph_objects as go
import plotly.express as px

from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %matplotlib inline

# %%
df = pd.read_csv('salary_data_cleaned.csv')
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'

# %%
def seniority(title):
    if 'Sr' in title.lower() or 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_simp'].value_counts(normalize=True)
# Out:
# data scientist    0.376011
# na                0.247978
# data engineer     0.160377
# analyst           0.137466
# manager           0.029650
# mle               0.029650
# director          0.018868
# Name: job_simp, dtype: float64

# %%
df['seniority'] = df['Job Title'].apply(seniority)
df['seniority'].value_counts(normalize=True)
# Out:
# na        0.700809
# senior    0.296496
# junior    0.002695
# Name: seniority, dtype: float64

# %%
# Fix state los Angeles

df.job_state.value_counts()
df['job_state'] = df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')

# %%
# Job description length

df['desc_len'] =df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python-yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
# Competitor count
df['Competitors_nr'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)

# %%
df['Competitors_nr']
# Out:
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 737    3
# 738    3
# 739    0
# 740    0
# 741    0
# Name: Competitors_nr, Length: 742, dtype: int64

# %%
# hourls wage to annual
# Number /1000

df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly ==1 else x.min_salary, axis=1)

# %%
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly ==1 else x.max_salary, axis=1)

# %%
df[df.hourly==1][['hourly','min_salary','max_salary']].head()
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50

# %%
# remove new line from job title

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python-yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'Competitors_nr'],
#       dtype='object')

# %%
df['company_txt'] = df['company_txt'].apply(lambda x: x.replace('\n',''))

# %%
df['company_txt']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_txt, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python-yn        R_yn  \
# count  742.000000  742.000000  742.000000  692.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   53.030347    0.528302    0.002695
# ...

# %%
df.Rating.hist()  # close to normal distribution
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 32 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          742 non-null    object
#  1   Salary Estimate    742 non-null    object
#  2   Job Description    742 non-null    object
#  3   Rating             742 non-null    float64
#  4   Company Name       742 non-null    object
#  5   Location           742 non-null    object
#  6   Headquarters       742 non-null    object
#  7   Size               742 non-null    object
#  8   Founded            742 non-null    int64
#  9   Type of ownership  742 non-null    object
#  10  Industry           742 non-null    object
#  11  Sector             742 non-null    object
#  12  Revenue            742 non-null    object
#  13  Competitors        742 non-null    object
#  14  hourly             742 non-null    int64
#  15  employer_provided  742 non-null    int64
# ...

# %%
df.avg_salary.hist()
# Out:
# <Axes: >

# %%
df.age.hist()
# Out:
# <Axes: >

# %%
df.desc_len.hist()
# Out:
# <Axes: >

# %%
df.boxplot(column=['age','avg_salary','Rating'])
# Out:
# <Axes: >

# %%
# Correlation between continious variable

df[['age','avg_salary','Rating','desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.023808 -0.079415  0.152058
# avg_salary  0.023808    1.000000  0.013492  0.078808
# Rating     -0.079415    0.013492  1.000000 -0.012281
# desc_len    0.152058    0.078808 -0.012281  1.000000

# %% [markdown]
# - negative correlation between age and desc len
#
#
# - older companies generally has longer description length

# %%
corr_map = df[['age','avg_salary','Rating','desc_len','Competitors_nr']].corr()

# %%
sns.heatmap(data= corr_map, annot=True, cmap='Blues',linewidths=3)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_txt', 'job_state', 'same_state', 'age', 'python-yn', 'R_yn',
#        'spark', 'aws', 'excel', 'job_simp', 'seniority', 'desc_len',
#        'Competitors_nr'],
#       dtype='object')

# %%
df_categorical = df[['Location', 'Headquarters', 'Size', 'Type of ownership', 'Industry',
    'Sector', 'Revenue','company_txt','job_state','same_state','python-yn', 'R_yn',
       'spark', 'aws', 'excel', 'job_simp', 'seniority',]]

# %%
for i in df_categorical.columns:
    cat_num = df_categorical[i].value_counts()

    fig = px.bar(cat_num, y=cat_num.index, x=cat_num, color=cat_num.index)
    fig.update_layout(
        title=f'Bar Plot for {i}',
        xaxis_title=i,
        yaxis_title='Count',
        xaxis_tickangle=45 
    )
    fig.show()
# Out:
# <div>                            <div id="319712b6-8d80-4840-a2b1-2f990d045d6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("319712b6-8d80-4840-a2b1-2f990d045d6e")) {                    Plotly.newPlot(                        "319712b6-8d80-4840-a2b1-2f990d045d6e",                        [{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>x=%{x}<extra></extra>","legendgroup":"MassMutual\n3.6","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"MassMutual\n3.6","offsetgroup":"MassMutual\n3.6","orientation":"h","showlegend":true,"textposition":"auto","x":[14],"xaxis":"x","y":["MassMutual\n3.6"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>x=%{x}<extra></extra>","legendgroup":"Reynolds American\n3.1",
# ...

# %%
for i in df_categorical[['Headquarters','Location','company_txt']].columns:
    cat_num = df_categorical[i].value_counts()[:5]
    plt.figure(figsize =(20,15))
    sns.barplot(y= cat_num.index, x= cat_num, palette='Set2') 
    plt.xlabel(i)
    plt.ylabel('Count')
    plt.show()

# %%
pd.pivot_table(data=df,index=['job_simp','seniority'],values='avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#                           avg_salary
# job_simp       seniority
# director       na          60.504983
# mle            senior      40.100321
# manager        na          38.461941
# analyst        senior      35.258397
# mle            na          35.116371
# na             na          32.301744
# data engineer  senior      31.043060
# na             senior      30.812374
# data scientist senior      29.996213
#                na          26.845369
# data engineer  na          23.824572
# analyst        na          17.730657

# %%
pd.pivot_table(data = df[df.job_simp =='data scientist'] ,index = ['job_state'],
               values='avg_salary').sort_values('avg_salary', ascending = False)
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df_pivots = df[['Rating','Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
       'hourly', 'employer_provided', 'min_salary', 'max_salary', 'python-yn', 'R_yn','spark', 'aws', 'excel','Competitors_nr','avg_salary']]

# %%
for i in df_pivots.columns:
    print(i)
    print(pd.pivot_table(df_pivots, index ='Rating', values='avg_salary').sort_values('avg_salary', ascending=False))
# Out:
# Rating
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
#  4.7    103.983871
#  4.3    102.468750
#  3.3    101.858974
#  4.2    100.442308
#  2.2     97.750000
#  4.6     97.250000
#  3.8     96.811475
#  2.1     95.900000
#  3.4     93.011364
#  1.9     87.500000
#  3.1     86.580000
#  3.0     85.588235
#  3.6     85.467391
#  2.8     83.928571
#  2.7     83.250000
#  2.3     81.500000
#  2.9     81.138889
#  4.8     80.277778
#  2.4     60.214286
# Type of ownership
#         avg_salary
# Rating
# -1.0    136.181818
#  5.0    134.700000
#  2.5    120.000000
#  4.5    117.714286
#  4.1    116.368421
#  3.9    113.071429
#  2.6    109.083333
#  4.4    108.606061
#  3.2    105.500000
#  4.0    105.340426
#  3.5    104.897959
#  3.7    104.131148
# ...

# %%
pd.pivot_table(df_pivots,index='Revenue',columns='python-yn',values='avg_salary',aggfunc='count')
# Out:
# python-yn                            0      1
# Revenue
# $1 to $2 billion (USD)            16.0   44.0
# $1 to $5 million (USD)             1.0    7.0
# $10 to $25 million (USD)          16.0   16.0
# $10+ billion (USD)                66.0   58.0
# $100 to $500 million (USD)        47.0   44.0
# $2 to $5 billion (USD)            17.0   22.0
# $25 to $50 million (USD)          24.0   16.0
# $5 to $10 billion (USD)            9.0   10.0
# $5 to $10 million (USD)            9.0    9.0
# $50 to $100 million (USD)         21.0   25.0
# $500 million to $1 billion (USD)  29.0   28.0
# -1                                 1.0    NaN
# Less than $1 million (USD)         1.0    3.0
# Unknown / Non-Applicable          93.0  110.0

# %%
# what actual word more popular to use in job desc

from wordcloud import WordCloud, ImageColorGenerator, STOPWORDS
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
words = " ".join(df['Job Description'])

def punctuation_stop(text):
    """remove punctuation and stop words"""
    filtered = []
    stop_words = set(stopwords.words('english'))
    word_tokens = word_tokenize(text)
    for w in word_tokens:
        if w not in stop_words and w.isalpha():
            filtered.append(w.lower())
    return filtered


words_filtered = punctuation_stop(words)

text = " ".join([ele for ele in words_filtered])

wc= WordCloud(background_color="white", random_state=1,stopwords=STOPWORDS, max_words = 2000, width =800, height = 1500)
wc.generate(text)

plt.figure(figsize=[10,10])
plt.imshow(wc,interpolation="bilinear")
plt.axis('off')
plt.show()

# %%
df.to_csv('eda_data_csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [128], line 1
# ----> 1 df_to_csv('eda_data_csv')
#
# NameError: name 'df_to_csv' is not defined
